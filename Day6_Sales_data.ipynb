# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_excel('Sales data Tablue.xlsx')

# %%
df
# Out:
#                         Region               Country   Item_Type  \
# 0             Central America   Antigua and Barbuda    Baby Food
# 1             Central America                 Panama      Snacks
# 2                       Europe        Czech Republic   Beverages
# 3                         Asia           North Korea      Cereal
# 4                         Asia             Sri Lanka      Snacks
# ...                        ...                   ...         ...
# 4995         Australia/Oceania           New Zealand  Vegetables
# 4996  Middle East/North Africa            Azerbaijan      Snacks
# 4997                      Asia               Myanmar   Baby Food
# 4998                    Europe               Finland     Clothes
# 4999        Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority           Order_Date  Year   Order_ID  \
# 0           Online              M           12/20/2013  2013  957081544
# ...

# %%
df.head()
# Out:
#              Region               Country  Item_Type Sales_Channel  \
# 0  Central America   Antigua and Barbuda   Baby Food        Online
# 1  Central America                 Panama     Snacks       Offline
# 2            Europe        Czech Republic  Beverages       Offline
# 3              Asia           North Korea     Cereal       Offline
# 4              Asia             Sri Lanka     Snacks       Offline
#
#   Order_Priority           Order_Date  Year   Order_ID            Ship_Date  \
# 0              M           12/20/2013  2013  957081544  2014-11-01 00:00:00
# 1              C  2010-05-07 00:00:00  2010  301644504            7/26/2010
# 2              C  2011-12-09 00:00:00  2011  478051030            9/29/2011
# 3              L            5/13/2010  2010  892599952            6/15/2010
# 4              C            7/20/2015  2015  571902596            7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  unit_per Profit  \
# ...

# %%
df.tail()
# Out:
#                         Region      Country   Item_Type Sales_Channel  \
# 4995         Australia/Oceania  New Zealand  Vegetables       Offline
# 4996  Middle East/North Africa   Azerbaijan      Snacks       Offline
# 4997                      Asia      Myanmar   Baby Food       Offline
# 4998                    Europe      Finland     Clothes        Online
# 4999        Sub-Saharan Africa     Tanzania  Vegetables        Online
#
#      Order_Priority           Order_Date  Year   Order_ID  \
# 4995              C  2015-03-04 00:00:00  2015  217984473
# 4996              L            8/17/2014  2014  169748055
# 4997              H           11/23/2016  2016  123256724
# 4998              L            4/22/2014  2014   13421235
# 4999              L  2011-08-07 00:00:00  2011  124535346
#
#                 Ship_Date  Units_Sold  Unit_SellingPrice  Unit_MakingCost  \
# 4995            4/20/2015        5305             668.27           502.54
# ...

# %%
df.describe()
# Out:
#               Year      Order_ID   Units_Sold  Unit_SellingPrice  \
# count  5000.000000  5.000000e+03  5000.000000        5000.000000
# mean   2013.318000  5.482709e+08  5030.926400         265.745564
# std       2.177665  2.595496e+08  2912.291375         218.716695
# min    2010.000000  1.342124e+07     2.000000           9.330000
# 25%    2011.000000  3.191029e+08  2456.250000          81.730000
# 50%    2013.000000  5.521214e+08  5122.000000         154.060000
# 75%    2015.000000  7.685650e+08  7574.500000         437.200000
# max    2017.000000  9.998797e+08  9999.000000         668.270000
#
#        Unit_MakingCost  unit_per Profit  Total profit
# count      5000.000000      5000.000000  5.000000e+03
# mean        187.494144        78.251420  3.925010e+05
# std         176.416280        53.403068  3.824200e+05
# min           6.920000         2.410000  1.687000e+01
# 25%          35.840000        25.060000  8.549190e+04
# 50%          97.440000        63.130000  2.796242e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          5000 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Year               5000 non-null   int64
#  7   Order_ID           5000 non-null   int64
#  8   Ship_Date          5000 non-null   object
#  9   Units_Sold         5000 non-null   int64
#  10  Unit_SellingPrice  5000 non-null   float64
#  11  Unit_MakingCost    5000 non-null   float64
#  12  unit_per Profit    5000 non-null   float64
#  13  Total profit       5000 non-null   float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 547.0+ KB

# %%
df['Units_Sold'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Removing the outliers from all numerical data

# %%
def calcu_lf_uf(q1, q3):
   IQR = q3-q1
   lower_fence = q1-(1.5*IQR)
   upper_fence = q3+(1.5*IQR)

   print("if-->", lower_fence, "uf-->", upper_fence)    
   return [lower_fence, upper_fence]

# %%
df['Units_Sold'].describe()
# Out:
# count    5000.000000
# mean     5030.926400
# std      2912.291375
# min         2.000000
# 25%      2456.250000
# 50%      5122.000000
# 75%      7574.500000
# max      9999.000000
# Name: Units_Sold, dtype: float64

# %%
[lf, uf] = calcu_lf_uf(2456.250, 7574.500)
# Out:
# if--> -5221.125 uf--> 15251.875

# %%
df['Units_Sold'] = np.where(df['Units_Sold']>uf, uf, df['Units_Sold'])
df['Units_Sold'] = np.where(df['Units_Sold']<lf, lf, df['Units_Sold'])

# %%
plt.boxplot(df['Units_Sold'])
plt.show()

# %%
df['Unit_SellingPrice'].describe()
# Out:
# count    5000.000000
# mean      265.745564
# std       218.716695
# min         9.330000
# 25%        81.730000
# 50%       154.060000
# 75%       437.200000
# max       668.270000
# Name: Unit_SellingPrice, dtype: float64

# %%
[lf, uf] = calcu_lf_uf(81.730, 437.200)
# Out:
# if--> -451.4749999999999 uf--> 970.405

# %%
df['Unit_SellingPrice'] = np.where(df['Unit_SellingPrice']>uf, uf, df['Unit_SellingPrice'])
df['Unit_SellingPrice'] = np.where(df['Unit_SellingPrice']<lf, lf, df['Unit_SellingPrice'])

# %%
plt.boxplot(df['Unit_SellingPrice'])
plt.show()

# %%
df['Unit_MakingCost'].describe()
# Out:
# count    5000.000000
# mean      187.494144
# std       176.416280
# min         6.920000
# 25%        35.840000
# 50%        97.440000
# 75%       263.330000
# max       524.960000
# Name: Unit_MakingCost, dtype: float64

# %%
[lf, uf] = calcu_lf_uf(35.840, 263.330)
# Out:
# if--> -305.395 uf--> 604.5649999999999

# %%
df['Unit_MakingCost'] = np.where(df['Unit_MakingCost']>uf, uf, df['Unit_MakingCost'])
df['Unit_MakingCost'] = np.where(df['Unit_MakingCost']<lf, lf, df['Unit_MakingCost'])

# %%
plt.boxplot(df['Unit_MakingCost']) 
plt.show()

# %%
df['unit_per Profit'].describe()
# Out:
# count    5000.000000
# mean       78.251420
# std        53.403068
# min         2.410000
# 25%        25.060000
# 50%        63.130000
# 75%       126.250000
# max       173.870000
# Name: unit_per Profit, dtype: float64

# %%
[lf, uf] = calcu_lf_uf(25.060000, 126.250000)
# Out:
# if--> -126.725 uf--> 278.03499999999997

# %%
df['unit_per Profit'] = np.where(df['unit_per Profit']>uf, uf, df['unit_per Profit'])
df['unit_per Profit'] = np.where(df['unit_per Profit']<lf, lf, df['unit_per Profit'])

# %%
plt.boxplot(df['unit_per Profit'])
plt.show()

# %%
df['Total profit'].describe()
# Out:
# count    5.000000e+03
# mean     3.925010e+05
# std      3.824200e+05
# min      1.687000e+01
# 25%      8.549190e+04
# 50%      2.796242e+05
# 75%      5.649067e+05
# max      1.726007e+06
# Name: Total profit, dtype: float64

# %%
[lf, uf] = calcu_lf_uf(8.549190e+04, 5.649067e+05)
# Out:
# if--> -633630.2999999999 uf--> 1284028.9

# %%
df['Total profit'] = np.where(df['Total profit']>uf, uf, df['Total profit'])
df['Total profit'] = np.where(df['Total profit']<lf, lf, df['Total profit'])

# %%
plt.boxplot(df['Total profit'])
plt.show()

# %%
plt.plot(df['Total profit'])

# %%
plt.plot(df['Total profit'], "*--")

# %%
plt.plot(df['Region'], df['Units_Sold'], "*")

# %%
df['Year'] = df['Year'].astype(object)

# %%
plt.bar(df['Year'], df['Units_Sold'], color="b")
# Out:
# <BarContainer object of 5000 artists>

# %%
df.groupby('Year')['Units_Sold'].mean().plot.bar(color="r")
# Out:
# <Axes: xlabel='Year'>

# %%
df.groupby('Item_Type')['Unit_SellingPrice'].mean().plot.bar(color=["r", "b", "k"])
# Out:
# <Axes: xlabel='Item_Type'>

# %%
df['Item_Type'].unique()
# Out:
# array(['Baby Food', 'Snacks', 'Beverages', 'Cereal', 'Personal Care',
#        'Clothes', 'Office Supplies', 'Cosmetics', 'Meat', 'Fruits',
#        'Vegetables', 'Household'], dtype=object)

# %%
plt.figure(figsize=(15, 5))
x_axis = df['Item_Type'].unique()
y_axis = df.groupby('Item_Type')['Unit_SellingPrice'].mean()

p = plt.bar(x_axis, y_axis, color=["r", "b", "k", "c", "y", "g"])
plt.bar_label(p)
plt.show()

# %%
plt.figure(figsize=(15, 5))
x_axis = df['Item_Type'].unique()
y_axis = df.groupby('Item_Type')['Units_Sold'].mean()

p = plt.bar(x_axis, y_axis, color=["r", "b", "k", "c", "y", "g"])
plt.bar_label(p)
plt.show()

# %%
plt.figure(figsize=(15, 5))
x_axis = df['Item_Type'].unique()
y_axis = df.groupby('Item_Type')['unit_per Profit'].mean()

p = plt.bar(x_axis, y_axis, color=["r", "b", "k", "c", "y", "g"])
plt.bar_label(p)
plt.show()

# %%
list = df['Country'].value_counts().head(10)

# %%
for i in list:
    print(i)
# Out:
# 40
# 40
# 38
# 38
# 38
# 37
# 36
# 36
# 36
# 36

# %%
plt.figure(figsize=(17, 5))
plt.bar_label(plt.bar(list.index, list.values, color=["r", "b", "k"]))
plt.show()
