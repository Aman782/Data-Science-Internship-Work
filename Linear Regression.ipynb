# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("car_done.csv")

# %%
df
# Out:
#      Unnamed: 0 Manufacturer    Model  Sales_in_thousands  \
# 0             0        Acura  Integra              16.919
# 1             1        Acura       TL              39.384
# 2             2        Acura       CL              14.114
# 3             3        Acura       RL               8.588
# 4             4         Audi       A4              20.397
# ..          ...          ...      ...                 ...
# 152         152        Volvo      V40               3.545
# 153         153        Volvo      S70              15.245
# 154         154        Volvo      V70              17.531
# 155         155        Volvo      C70               3.493
# 156         156        Volvo      S80              18.969
#
#      four_year_resale_value Vehicle_type  Price_in_thousands  Engine_size  \
# 0                    16.360    Passenger               21.50          1.8
# 1                    19.875    Passenger               28.40          3.2
# 2                    18.225    Passenger                 NaN          3.2
# 3                    29.725    Passenger               42.00          3.5
# 4                    22.255    Passenger               23.99          1.8
# ..                      ...          ...                 ...          ...
# 152                     NaN    Passenger               24.40          1.9
# 153                     NaN    Passenger               27.50          2.4
# 154                     NaN    Passenger               28.80          2.4
# 155                     NaN    Passenger               45.50          2.3
# 156                     NaN    Passenger               36.00          2.9
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0         140.0      101.2   67.3   172.4        2.639           13.2
# 1         225.0      108.1   70.3   192.9        3.517           17.2
# 2         225.0      106.9   70.6   192.0        3.470           17.2
# 3         210.0      114.6   71.4   196.6        3.850           18.0
# 4         150.0      102.6   68.2   178.0        2.998           16.4
# ..          ...        ...    ...     ...          ...            ...
# 152       160.0      100.5   67.6   176.6        3.042           15.8
# 153       168.0      104.9   69.3   185.9        3.208           17.9
# 154       168.0      104.9   69.3   186.2        3.259           17.9
# 155       236.0      104.9   71.5   185.7        3.601           18.5
# 156       201.0      109.9   72.1   189.8        3.600           21.1
#
#      Fuel_efficiency Latest_Launch  Power_perf_factor
# 0               28.0      2/2/2012          58.280150
# 1               25.0      6/3/2011          91.370778
# 2               26.0      1/4/2012                NaN
# 3               22.0     3/10/2011          91.389779
# 4               27.0     10/8/2011          62.777639
# ..               ...           ...                ...
# 152             25.0     9/21/2011          66.498812
# 153             25.0    11/24/2012          70.654495
# 154             25.0     6/25/2011          71.155978
# 155             23.0     4/26/2011         101.623357
# 156             24.0    11/14/2011          85.735655
#
# [157 rows x 17 columns]

# %%
df.drop(columns = "Unnamed: 0",inplace = True)

# %%
df.isnull().sum()
# Out:
# Manufacturer               0
# Model                      0
# Sales_in_thousands         0
# four_year_resale_value    36
# Vehicle_type               0
# Price_in_thousands         2
# Engine_size                1
# Horsepower                 1
# Wheelbase                  1
# Width                      1
# Length                     1
# Curb_weight                2
# Fuel_capacity              1
# Fuel_efficiency            3
# Latest_Launch              0
# Power_perf_factor          2
# dtype: int64

# %%
df["four_year_resale_value"].fillna(value=14.16,inplace = True)
# Out:
# C:\Users\amanp\AppData\Local\Temp\ipykernel_34344\1793132218.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["four_year_resale_value"].fillna(value=14.16,inplace = True)

# %%
df.ffill(inplace=True)

# %%
df["Sales_in_thousands"]=np.where(df["Sales_in_thousands"]>257.0863424,257.0863424,df["Sales_in_thousands"])
df["Engine_size"]=np.where(df["Engine_size"]>6.194856356,6.194856356,df["Engine_size"])
df["Horsepower"]=np.where(df["Horsepower"]>356.0496805,356.0496805,df["Horsepower"])
df["Fuel_efficiency"]=np.where(df["Fuel_efficiency"]>36.69,36.69,df["Fuel_efficiency"])
df["Power_perf_factor"]=np.where(df["Power_perf_factor"]>152.4,154.4,df["Power_perf_factor"])

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                  14.160
# 153        Volvo      S70              15.245                  14.160
# 154        Volvo      V70              17.531                  14.160
# 155        Volvo      C70               3.493                  14.160
# 156        Volvo      S80              18.969                  14.160
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# 1      Passenger               28.40          3.2       225.0      108.1
# 2      Passenger               28.40          3.2       225.0      106.9
# 3      Passenger               42.00          3.5       210.0      114.6
# 4      Passenger               23.99          1.8       150.0      102.6
# ..           ...                 ...          ...         ...        ...
# 152    Passenger               24.40          1.9       160.0      100.5
# 153    Passenger               27.50          2.4       168.0      104.9
# 154    Passenger               28.80          2.4       168.0      104.9
# 155    Passenger               45.50          2.3       236.0      104.9
# 156    Passenger               36.00          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0     67.3   172.4        2.639           13.2             28.0      2/2/2012
# 1     70.3   192.9        3.517           17.2             25.0      6/3/2011
# 2     70.6   192.0        3.470           17.2             26.0      1/4/2012
# 3     71.4   196.6        3.850           18.0             22.0     3/10/2011
# 4     68.2   178.0        2.998           16.4             27.0     10/8/2011
# ..     ...     ...          ...            ...              ...           ...
# 152   67.6   176.6        3.042           15.8             25.0     9/21/2011
# 153   69.3   185.9        3.208           17.9             25.0    11/24/2012
# 154   69.3   186.2        3.259           17.9             25.0     6/25/2011
# 155   71.5   185.7        3.601           18.5             23.0     4/26/2011
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 2            91.370778
# 3            91.389779
# 4            62.777639
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [157 rows x 16 columns]

# %%
df.drop(columns="Latest_Launch",inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Manufacturer            157 non-null    object
#  1   Model                   157 non-null    object
#  2   Sales_in_thousands      157 non-null    float64
#  3   four_year_resale_value  157 non-null    float64
#  4   Vehicle_type            157 non-null    object
#  5   Price_in_thousands      157 non-null    float64
#  6   Engine_size             157 non-null    float64
#  7   Horsepower              157 non-null    float64
#  8   Wheelbase               157 non-null    float64
#  9   Width                   157 non-null    float64
#  10  Length                  157 non-null    float64
#  11  Curb_weight             157 non-null    float64
#  12  Fuel_capacity           157 non-null    float64
#  13  Fuel_efficiency         157 non-null    float64
#  14  Power_perf_factor       157 non-null    float64
# dtypes: float64(12), object(3)
# memory usage: 18.5+ KB

# %%
df.select_dtypes(float).corr()
# Out:
#                         Sales_in_thousands  four_year_resale_value  \
# Sales_in_thousands                1.000000               -0.275195
# four_year_resale_value           -0.275195                1.000000
# Price_in_thousands               -0.359714                0.785014
# Engine_size                      -0.015914                0.436875
# Horsepower                       -0.253468                0.652923
# Wheelbase                         0.293295               -0.048975
# Width                             0.094194                0.166638
# Length                            0.212038                0.039963
# Curb_weight                      -0.038584                0.274711
# Fuel_capacity                     0.042253                0.259890
# Fuel_efficiency                   0.034046               -0.337954
# Power_perf_factor                -0.282870                0.700767
#
#                         Price_in_thousands  Engine_size  Horsepower  \
# Sales_in_thousands               -0.359714    -0.015914   -0.253468
# four_year_resale_value            0.785014     0.436875    0.652923
# Price_in_thousands                1.000000     0.621087    0.838737
# Engine_size                       0.621087     1.000000    0.821433
# Horsepower                        0.838737     0.821433    1.000000
# Wheelbase                         0.110593     0.512044    0.318941
# Width                             0.328493     0.707140    0.551218
# Length                            0.156519     0.575437    0.426233
# Curb_weight                       0.529592     0.796893    0.638985
# Fuel_capacity                     0.422945     0.689184    0.514136
# Fuel_efficiency                  -0.501567    -0.758767   -0.615726
# Power_perf_factor                 0.898955     0.803347    0.992494
#
#                         Wheelbase     Width    Length  Curb_weight  \
# Sales_in_thousands       0.293295  0.094194  0.212038    -0.038584
# four_year_resale_value  -0.048975  0.166638  0.039963     0.274711
# Price_in_thousands       0.110593  0.328493  0.156519     0.529592
# Engine_size              0.512044  0.707140  0.575437     0.796893
# Horsepower               0.318941  0.551218  0.426233     0.638985
# Wheelbase                1.000000  0.684403  0.839084     0.652182
# Width                    0.684403  1.000000  0.712321     0.722272
# Length                   0.839084  0.712321  1.000000     0.627516
# Curb_weight              0.652182  0.722272  0.627516     1.000000
# Fuel_capacity            0.651700  0.652846  0.556968     0.861416
# Fuel_efficiency         -0.498465 -0.596958 -0.427817    -0.830916
# Power_perf_factor        0.283667  0.519456  0.379893     0.635683
#
#                         Fuel_capacity  Fuel_efficiency  Power_perf_factor
# Sales_in_thousands           0.042253         0.034046          -0.282870
# four_year_resale_value       0.259890        -0.337954           0.700767
# Price_in_thousands           0.422945        -0.501567           0.898955
# Engine_size                  0.689184        -0.758767           0.803347
# Horsepower                   0.514136        -0.615726           0.992494
# Wheelbase                    0.651700        -0.498465           0.283667
# Width                        0.652846        -0.596958           0.519456
# Length                       0.556968        -0.427817           0.379893
# Curb_weight                  0.861416        -0.830916           0.635683
# Fuel_capacity                1.000000        -0.818173           0.511270
# Fuel_efficiency             -0.818173         1.000000          -0.610440
# Power_perf_factor            0.511270        -0.610440           1.000000

# %%
# df1 = pd.get_dummies(df,columns=['Manufacturer', 'Model', 'Vehicle_type'],drop_first=True)
df1 = pd.get_dummies(df,columns = ['Vehicle_type'],drop_first=True)

# %%
df.select_dtypes(object).columns
# Out:
# Index(['Manufacturer', 'Model', 'Vehicle_type'], dtype='object')

# %%
df1
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                  14.160
# 153        Volvo      S70              15.245                  14.160
# 154        Volvo      V70              17.531                  14.160
# 155        Volvo      C70               3.493                  14.160
# 156        Volvo      S80              18.969                  14.160
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 2                 28.40          3.2       225.0      106.9   70.6   192.0
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor  \
# 0          2.639           13.2             28.0          58.280150
# 1          3.517           17.2             25.0          91.370778
# 2          3.470           17.2             26.0          91.370778
# 3          3.850           18.0             22.0          91.389779
# 4          2.998           16.4             27.0          62.777639
# ..           ...            ...              ...                ...
# 152        3.042           15.8             25.0          66.498812
# 153        3.208           17.9             25.0          70.654495
# 154        3.259           17.9             25.0          71.155978
# 155        3.601           18.5             23.0         101.623357
# 156        3.600           21.1             24.0          85.735655
#
#      Vehicle_type_Passenger
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# ..                      ...
# 152                    True
# 153                    True
# 154                    True
# 155                    True
# 156                    True
#
# [157 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df1
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                  14.160
# 153        Volvo      S70              15.245                  14.160
# 154        Volvo      V70              17.531                  14.160
# 155        Volvo      C70               3.493                  14.160
# 156        Volvo      S80              18.969                  14.160
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 2                 28.40          3.2       225.0      106.9   70.6   192.0
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor  \
# 0          2.639           13.2             28.0          58.280150
# 1          3.517           17.2             25.0          91.370778
# 2          3.470           17.2             26.0          91.370778
# 3          3.850           18.0             22.0          91.389779
# 4          2.998           16.4             27.0          62.777639
# ..           ...            ...              ...                ...
# 152        3.042           15.8             25.0          66.498812
# 153        3.208           17.9             25.0          70.654495
# 154        3.259           17.9             25.0          71.155978
# 155        3.601           18.5             23.0         101.623357
# 156        3.600           21.1             24.0          85.735655
#
#      Vehicle_type_Passenger
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# ..                      ...
# 152                    True
# 153                    True
# 154                    True
# 155                    True
# 156                    True
#
# [157 rows x 15 columns]

# %%
x = df1[['four_year_resale_value',
       'Vehicle_type_Passenger', 'Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
       'Fuel_efficiency', 'Power_perf_factor']]
y = df1["Sales_in_thousands"]

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Power_perf_factor'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=88)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.38604856826088785

# %%
model.score(X_test, y_test)
# Out:
# -624834326.0041522

# %%
df1 = pd.get_dummies(df, columns=["Vehicle_type"], drop_first=True)

# %%
df1
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                  14.160
# 153        Volvo      S70              15.245                  14.160
# 154        Volvo      V70              17.531                  14.160
# 155        Volvo      C70               3.493                  14.160
# 156        Volvo      S80              18.969                  14.160
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 2                 28.40          3.2       225.0      106.9   70.6   192.0
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor  \
# 0          2.639           13.2             28.0          58.280150
# 1          3.517           17.2             25.0          91.370778
# 2          3.470           17.2             26.0          91.370778
# 3          3.850           18.0             22.0          91.389779
# 4          2.998           16.4             27.0          62.777639
# ..           ...            ...              ...                ...
# 152        3.042           15.8             25.0          66.498812
# 153        3.208           17.9             25.0          70.654495
# 154        3.259           17.9             25.0          71.155978
# 155        3.601           18.5             23.0         101.623357
# 156        3.600           21.1             24.0          85.735655
#
#      Vehicle_type_Passenger
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# ..                      ...
# 152                    True
# 153                    True
# 154                    True
# 155                    True
# 156                    True
#
# [157 rows x 15 columns]

# %%
df1.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width',
#        'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency',
#        'Power_perf_factor', 'Vehicle_type_Passenger'],
#       dtype='object')

# %%
y = df1["Sales_in_thousands"]
x = df1[['four_year_resale_value',
       'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width',
       'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency',
       'Power_perf_factor', 'Vehicle_type_Passenger']]

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=88)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (109, 12)
# (48, 12)
# (109,)
# (48,)

# %%
X_train.columns
# Out:
# Index(['four_year_resale_value', 'Price_in_thousands', 'Engine_size',
#        'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight',
#        'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor',
#        'Vehicle_type_Passenger'],
#       dtype='object')

# %%
y_train
# Out:
# 55     220.650
# 104     27.308
# 36       4.734
# 109     38.554
# 98      11.592
#         ...
# 62      41.184
# 101     42.643
# 148      9.569
# 106     54.158
# 32      13.462
# Name: Sales_in_thousands, Length: 109, dtype: float64

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %%
X_train['Vehicle_type_Passenger'] = np.where(X_train['Vehicle_type_Passenger']==True, 1, 0)

# %%
print(X_train)
# Out:
#      const  four_year_resale_value  Price_in_thousands  Engine_size  \
# 55     1.0                   7.850              12.050          2.5
# 104    1.0                  15.380              26.399          3.3
# 36     1.0                  12.545              19.045          2.5
# 109    1.0                  14.160              24.150          3.5
# 98     1.0                  14.160              41.600          3.2
# ..     ...                     ...                 ...          ...
# 62     1.0                   5.860               9.699          1.5
# 101    1.0                   8.450              13.499          1.8
# 148    1.0                  16.575              19.990          2.0
# 106    1.0                  14.160              22.799          3.3
# 32     1.0                  17.325              28.340          3.5
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 55        119.0      117.5   69.4   200.7        3.086           20.0
# 104       170.0      112.2   74.9   194.8        3.991           20.0
# 36        163.0      103.7   69.1   190.2        2.879           15.9
# 109       215.0      109.0   73.6   195.9        3.455           18.0
# 98        215.0      105.9   67.8   180.3        3.213           16.4
# ..          ...        ...    ...     ...          ...            ...
# 62         92.0       96.1   65.7   166.7        2.240           11.9
# 101       126.0       99.8   67.3   177.5        2.593           13.2
# 148       115.0       97.4   66.7   160.4        3.079           13.7
# 106       170.0      104.3   70.4   178.0        3.821           19.4
# 32        253.0      113.0   74.4   207.7        3.564           17.0
#
#      Fuel_efficiency  Power_perf_factor  Vehicle_type_Passenger
# 55              23.0          47.389531                       0
# 104             21.0          71.171664                       0
# 36              24.0          65.650508                       1
# 109             25.0          86.272523                       1
# 98              26.0          92.925792                       1
# ..               ...                ...                     ...
# 62              31.0          36.672284                       1
# 101             30.0          50.241978                       1
# 148             26.0          48.907372                       1
# 106             18.0          69.782944                       0
# 32              23.0         101.329281                       1
#
# [109 rows x 13 columns]

# %%
model1 = sm.OLS(y_train, X_train).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     5.030
# Date:                Tue, 09 Jul 2024   Prob (F-statistic):           1.97e-06
# Time:                        09:47:58   Log-Likelihood:                -567.58
# No. Observations:                 109   AIC:                             1161.
# Df Residuals:                      96   BIC:                             1196.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   -388.1899    164.666     -2.357      0.020    -715.048     -61.331
# four_year_resale_value     0.6718      0.850      0.791      0.431      -1.015       2.359
# Price_in_thousands      9.003e+07   1.95e+08      0.462      0.645   -2.97e+08    4.77e+08
# Engine_size             6.081e+07   1.32e+08      0.462      0.645      -2e+08    3.22e+08
# Horsepower              8.255e+07   1.79e+08      0.462      0.645   -2.72e+08    4.37e+08
# Wheelbase                  2.2480      1.261      1.783      0.078      -0.255       4.751
# Width                      2.8027      2.524      1.110      0.270      -2.208       7.814
# Length                     0.6574      0.792      0.830      0.408      -0.914       2.229
# Curb_weight              -46.4878     21.823     -2.130      0.036     -89.806      -3.169
# Fuel_capacity              1.4575      2.800      0.520      0.604      -4.101       7.016
# Fuel_efficiency            1.6048      2.668      0.601      0.549      -3.692       6.902
# Power_perf_factor      -2.334e+08   5.05e+08     -0.462      0.645   -1.24e+09    7.69e+08
# Vehicle_type_Passenger   -25.0205     20.532     -1.219      0.226     -65.776      15.735
# ==============================================================================
# Omnibus:                       48.026   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.592
# Skew:                           1.645   Prob(JB):                     4.39e-29
# Kurtosis:                       7.234   Cond. No.                     4.00e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.48e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
df1["Sales_log"] = np.log(df1["Sales_in_thousands"])

# %%
y = df1["Sales_log"]
x = df1[['four_year_resale_value', 'Price_in_thousands', 'Length', 'Horsepower',
       'Vehicle_type_Passenger']]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=88)

# %%
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)
X_train['Vehicle_type_Passenger'] = np.where(X_train['Vehicle_type_Passenger']==True, 1, 0)
model2 = sm.OLS(y_train, X_train).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Sales_in_thousands   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     5.030
# Date:                Tue, 09 Jul 2024   Prob (F-statistic):           1.97e-06
# Time:                        10:25:49   Log-Likelihood:                -567.58
# No. Observations:                 109   AIC:                             1161.
# Df Residuals:                      96   BIC:                             1196.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   -388.1899    164.666     -2.357      0.020    -715.048     -61.331
# four_year_resale_value     0.6718      0.850      0.791      0.431      -1.015       2.359
# Price_in_thousands      9.003e+07   1.95e+08      0.462      0.645   -2.97e+08    4.77e+08
# Engine_size             6.081e+07   1.32e+08      0.462      0.645      -2e+08    3.22e+08
# Horsepower              8.255e+07   1.79e+08      0.462      0.645   -2.72e+08    4.37e+08
# Wheelbase                  2.2480      1.261      1.783      0.078      -0.255       4.751
# Width                      2.8027      2.524      1.110      0.270      -2.208       7.814
# Length                     0.6574      0.792      0.830      0.408      -0.914       2.229
# Curb_weight              -46.4878     21.823     -2.130      0.036     -89.806      -3.169
# Fuel_capacity              1.4575      2.800      0.520      0.604      -4.101       7.016
# Fuel_efficiency            1.6048      2.668      0.601      0.549      -3.692       6.902
# Power_perf_factor      -2.334e+08   5.05e+08     -0.462      0.645   -1.24e+09    7.69e+08
# Vehicle_type_Passenger   -25.0205     20.532     -1.219      0.226     -65.776      15.735
# ==============================================================================
# Omnibus:                       48.026   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.592
# Skew:                           1.645   Prob(JB):                     4.39e-29
# Kurtosis:                       7.234   Cond. No.                     4.00e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.48e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Sales_log   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     20.26
# Date:                Tue, 09 Jul 2024   Prob (F-statistic):           4.99e-14
# Time:                        10:25:53   Log-Likelihood:                -140.75
# No. Observations:                 109   AIC:                             293.5
# Df Residuals:                     103   BIC:                             309.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7746      1.301     -0.595      0.553      -3.354       1.805
# four_year_resale_value     0.0155      0.014      1.133      0.260      -0.012       0.043
# Price_in_thousands        -0.0579      0.014     -4.186      0.000      -0.085      -0.030
# Length                     0.0326      0.008      4.078      0.000       0.017       0.048
# Horsepower                -0.0016      0.004     -0.415      0.679      -0.009       0.006
# Vehicle_type_Passenger    -0.5487      0.206     -2.665      0.009      -0.957      -0.140
# ==============================================================================
# Omnibus:                       21.191   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.530
# Skew:                          -0.897   Prob(JB):                     8.63e-08
# Kurtosis:                       4.986   Cond. No.                     4.01e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import seaborn as sns

# %%
sns.distplot(df["Sales_in_thousands"])
# Out:
# C:\Users\amanp\AppData\Local\Temp\ipykernel_34344\785352375.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Sales_in_thousands"])
# <Axes: xlabel='Sales_in_thousands', ylabel='Density'>

# %%
actual = np.exp(y_train)
pre = np.exp(model2.predict(X_train))
error = actual-pre

# %%
mse = np.mean(np.square(error))
print("MSE:", mse)

rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# MSE: 2177.55541354952
# RMSE: 46.66428413197314

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 0.49583605403107356

# %%
lr.score(X_test, y_test)
# Out:
# 0.3502190030460499

# %%
X_train1 = X_train

# %%
X_train["pre_sales"] = lr.predict(X_train)

# %%
X_train1["pre_sales"] = np.exp(X_train1["pre_sales"])

# %%
X_train.drop(columns="pre_sales",inplace=True)

# %%
lr.intercept_
# Out:
# -0.7746314373343455

# %%
lr.coef_
# Out:
# array([ 0.        ,  0.01551759, -0.05790424,  0.03255937, -0.00162732,
#        -0.54868501])

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
actual = np.exp(y_train)

# %%
pre = np.exp(lr.predict(X_train))

# %%
MAP = mean_absolute_percentage_error(actual, pre)

# %%
MSE = mean_squared_error(actual, pre)
MAE = mean_absolute_error(actual, pre)

# %%
print("MAP", MAP)
print("MSE", MSE)
print("MAE", MAE)
# Out:
# MAP 1.1798025524876605
# MSE 2177.5554135494717
# MAE 27.157593635550096

# %% [markdown]
# # Import Data
# # null values, duplicated
# # unwanted columns
# # outliers
# # dummy
# # y = target variable
# # x = independent variable
# # tain test split()
# # lr = LinearRegression()
# # lr.fit(x_train, y_train)
# # lr.score(x_train, y_train)
# # lr.predict
#
# # print(MSE)
# # print(RMSE)
# # print(MAE)
# # print(MAPE)
